# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
print("1.Sl: ",df["SepalLengthCm"].dtype)
print("2.Sw: ",df["SepalWidthCm"].dtype)
print("3.pl: ",df["PetalLengthCm"].dtype)
print("4.pw: ",df["PetalWidthCm"].dtype)
print("5.specoes: ",df["Species"].dtype)
# Out:
# 1.Sl:  float64
# 2.Sw:  float64
# 3.pl:  float64
# 4.pw:  float64
# 5.specoes:  object

# %%
sns.histplot(x="SepalLengthCm",data=df,kde=True)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.histplot(x="SepalWidthCm",data=df,kde=True)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Count'>

# %%
sns.histplot(x="PetalLengthCm",data=df,kde=True)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
sns.histplot(x="PetalWidthCm",data=df,kde=True)
plt.title("Petal width")
plt.xlabel("Petal width")
plt.ylabel("Count")
plt.show()

# %%
sns.histplot(x="Species",data=df)
# Out:
# <Axes: xlabel='Species', ylabel='Count'>

# %%
sns.boxplot(data=df['SepalLengthCm'])
# Out:
# <Axes: ylabel='SepalLengthCm'>

# %%
sns.boxplot(data=df,x=df['SepalWidthCm'])
# Out:
# <Axes: xlabel='SepalWidthCm'>

# %%
sns.boxplot(data=df,x=df['PetalWidthCm'])
# Out:
# <Axes: xlabel='PetalWidthCm'>

# %%
sns.boxplot(x=df['PetalWidthCm'],data=df)
# Out:
# <Axes: xlabel='PetalWidthCm'>

# %%
sns.boxplot(x=df['Species'],data=df)
# Out:
# <Axes: xlabel='Species'>

# %%
df=df.drop("Id",axis=1)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >
